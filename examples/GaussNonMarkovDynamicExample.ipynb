# %% [markdown]
# Continuous-time model
# ---
#
# Let's order the infection times $t_{\pi_{1}}<t_{\pi_{2}}<\dots<t_{\pi_{N}}$
# . Let $\lambda_{i}\left(t\right)$ be a time-dependent transmission
# rate and $L_{i}\left(t\right)=\int_{0}^{t}\lambda_{ij}\left(s\right)ds$
# its primitive. Then $\rho_{i}\left(t_i; t_j\right)=\lambda_{i}\left(t_i\right)e^{-\int_{t_j}^{t_i}\lambda_{i}\left(s\right)ds} = \lambda_{i}\left(t_j\right)e^{L_{i}(t_j) - L_{i}(t_i) }$
# will be the transmission ``delay'' density distribution.

# %% [markdown]
# \begin{align*}p\left(t_{1},\dots,t_{N}\right) & =\prod_{i=1}^{N}\lim_{ds\to0^{+}}\frac{\prod_{j\in\partial i:t_{j}<t_{i}}e^{L_{i}(t_{j})-L_{i}(t_{i}-ds)}-\prod_{j\in\partial i:t_{j}<t_{i}}e^{L_{i}(t_{j})-L_{i}(t_{i})}}{ds}\\
#  & =\prod_{i=1}^{N}\frac{d}{ds}_{|s=0}\prod_{j\in\partial i:t_{j}<t_{i}}e^{L_{i}(t_{j})-L_{i}(t_{i}-ds)}\\
#  & =\prod_{i=1}^{N}\left\{ \left(\prod_{j\in\partial i:t_{j}<t_{i}}e^{L_{i}(t_{j})-L_{i}(t_{i})}\right)\sum_{j\in\partial i:t_{j}<t_{i}}\lambda_{i}\left(t_{i}\right)\right\} \\
# \mathcal{L}_{0}\left(t_{1},\dots,t_{N}\right) & =\log p\left(t_{1},\dots,t_{N}\right)\\
#  & =-\sum_{i=1}^{N}\left\{ \sum_{j\in\partial i:t_{j}<t_{i}}\left(L_{i}(t_{i})-L_{i}(t_{j})\right)-\log\left(\sum_{j\in\partial i:t_{j}<t_{i}}\lambda_{i}\left(t_{i}\right)\right)\right\}
# \end{align*}

# %% [markdown]
# Note that $$\int_{t_j}^{t_i} \rho_{i}(s; t_j) ds = 1-e^{-\left(L_{i}(t_i) - L_{i}(t_j)\right)}$$ so $$\lambda_{i}(t) = -\frac{d}{dt}\log \left(1-\int_{t_j}^{t_i} \rho_{i}(s) ds\right)$$

# %% [markdown]
# \begin{align}\lambda(t) & =ae^{-\left(\frac{t-b}{c}\right)^{2}}\\
# \frac{x-b}{c} & =\frac{y}{\sqrt{2}}\\
# dx & =\frac{c}{\sqrt{2}}dy\\
# L(t)=\int_{0}^{t}ae^{-\left(\frac{x-b}{c}\right)^{2}}dx & = ac\int_{\frac{0-b}{c}}^{\frac{t-b}{c}}e^{-y^{2}}dy\\
#  & =ac\sqrt{\pi}\frac{1}{\sqrt{\pi}}\int_{-\frac{b}{c}}^{\frac{t-b}{c}}e^{-y^{2}}dy\\
#  & =\frac{ac\sqrt{\pi}}{2}\left(\mathrm{erfc}\left(-\frac{t-b}{c}\right)-\mathrm{erfc}\left(\frac{b}{c}\right)\right)\\
# \rho_{i}\left(t_{i};t_{j}\right) & =\lambda_{i}\left(t_{i}\right)e^{-\int_{t_{j}}^{t_{i}}\lambda_{i}\left(s\right)ds}=\lambda_{i}\left(t_{i}\right)e^{L_{i}(t_{j})-L_{i}(t_{i})}\\
# \frac{d}{ds}-e^{L_{i}(t_{j})-L_{i}(s)} & =\lambda\left(s\right)e^{L_{i}(t_{j})-L_{i}(s)}=\rho_{i}\left(s;t_{j}\right)\\
# \end{align}

# %% [markdown]
# Sampling
# ---
# \begin{align}
# \int_{t_{j}}^{t}\rho(s;t_{j})ds & =1-e^{L_{i}(t_{j})-L_{i}(t)}=1-r\sim U(0,1)\\
# e^{L_{i}(t_{j})-L_{i}(t)} & =r\\
# L_{i}(t) & =L_{i}\left(t_{j}\right)-\log(r)\\
# \mathrm{erfc}\left(-\frac{t-b}{c}\right) & =\frac{2}{ac\sqrt{\pi}}\left(L_{i}\left(t_{j}\right)-\log(r)\right)+\mathrm{erfc}\left(\frac{b}{c}\right)\\
# t & =-c\,\mathrm{ierfc}\left(\frac{2}{ac\sqrt{\pi}}\left(L_{i}\left(t_{j}\right)-\log(r)\right)+\mathrm{erfc}\left(\frac{b}{c}\right)\right)+b
# \end{align}

# %% [markdown]
# Data generation
# ===

# %%
using Causality
using IntervalUnionArithmetic
# Out:
# ┌ Info: Precompiling Causality [943c2df0-3341-4665-8895-8aff0dd63d80]
# └ @ Base loading.jl:1423
# WARNING: Method definition union(IntervalArithmetic.Interval{T} where T<:Real, IntervalArithmetic.Interval{T} where T<:Real) in module IntervalArithmetic at /home/ab/.julia/packages/IntervalArithmetic/UR6Qe/src/intervals/set_operations.jl:137 overwritten in module IntervalUnionArithmetic at /home/ab/.julia/packages/IntervalUnionArithmetic/4sZoD/src/interval_unions.jl:52.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition \(IntervalUnionArithmetic.IntervalUnion{T} where T<:Real, IntervalUnionArithmetic.IntervalUnion{T} where T<:Real) in module IntervalUnionArithmetic at /home/ab/.julia/packages/IntervalUnionArithmetic/4sZoD/src/set_operations.jl:79 overwritten at /home/ab/.julia/packages/IntervalUnionArithmetic/4sZoD/src/set_operations.jl:77.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition reweighted_post(Any, Any, Any) in module Causality at /home/ab/src/Causality/src/sampler.jl:106 overwritten at /home/ab/src/Causality/src/sampler.jl:122.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition reweighted_post##kw(Any, typeof(Causality.reweighted_post), Any, Any, Any) in module Causality at /home/ab/src/Causality/src/sampler.jl:106 overwritten at /home/ab/src/Causality/src/sampler.jl:122.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: using Graphs.density in module Causality conflicts with an existing identifier.

# %%
T, N = 20.0, 30
ρ = 3/N
G = Causality.makeGNP(N,ρ)
# Out:
# Causality.SparseMatrixDiGraph{Int64}(sparse([12, 15, 30, 6, 9, 22, 26, 30, 11, 18  …  26, 7, 24, 1, 2, 6, 11, 13, 21, 23], [1, 1, 1, 2, 2, 2, 2, 2, 3, 3  …  28, 29, 29, 30, 30, 30, 30, 30, 30, 30], [π, π, π, π, π, π, π, π, π, π  …  π, π, π, π, π, π, π, π, π, π], 30, 30), sparse([12, 15, 30, 6, 9, 22, 26, 30, 11, 18  …  26, 7, 24, 1, 2, 6, 11, 13, 21, 23], [1, 1, 1, 2, 2, 2, 2, 2, 3, 3  …  28, 29, 29, 30, 30, 30, 30, 30, 30, 30], [45, 55, 92, 19, 30, 69, 81, 93, 39, 60  …  82, 28, 79, 3, 8, 25, 44, 52, 68, 75], 30, 30))

# %%
#Let us create a vector of contacts
using Graphs
V = map(edges(G)) do _
    r = T*rand()
    s = min(r + rand()*5, T)
    mask = Interval(r,s)
    n_contacts = rand(1:10)
    for cont ∈ 1:n_contacts
        r = T*rand()
        s = min(r + rand()*5, T) 
        mask = mask ∪ Interval(r,s)
    end
    MaskedRate(UnitRate(), mask)
end
# Out:
# 98-element Vector{MaskedRate{UnitRate}}:
#  MaskedRate{UnitRate}(UnitRate(), [0.454799, 7.106] ∪ [11.9589, 15.3652] ∪ [19.8801, 20])
#  MaskedRate{UnitRate}(UnitRate(), [2.54016, 13.4335]ᵤ)
#  MaskedRate{UnitRate}(UnitRate(), [0.024499, 1.33094] ∪ [6.60882, 11.2878] ∪ [11.9372, 20])
#  MaskedRate{UnitRate}(UnitRate(), [6.39675, 10.1958] ∪ [16.9478, 17.3514])
#  MaskedRate{UnitRate}(UnitRate(), [6.85486, 8.78716] ∪ [9.69218, 12.5564] ∪ [13.3717, 18.3409] ∪ [18.7134, 20])
#  MaskedRate{UnitRate}(UnitRate(), [3.76899, 12.4926] ∪ [12.5161, 14.4432] ∪ [15.5046, 16.8708] ∪ [17.5453, 20])
#  MaskedRate{UnitRate}(UnitRate(), [3.66405, 5.85915] ∪ [6.69422, 11.0953] ∪ [11.2866, 18.8887] ∪ [19.8548, 20])
#  MaskedRate{UnitRate}(UnitRate(), [6.81077, 8.07664] ∪ [8.37939, 12.825] ∪ [16.8257, 20])
#  MaskedRate{UnitRate}(UnitRate(), [0.023722, 3.54876]ᵤ)
#  MaskedRate{UnitRate}(UnitRate(), [0.0595551, 0.118956] ∪ [1.48491, 4.98695] ∪ [8.26316, 12.7452] ∪ [15.4247, 20])
#  MaskedRate{UnitRate}(UnitRate(), [4.14237, 8.16773] ∪ [10.9972, 11.0427] ∪ [13.5787, 14.4565] ∪ [16.0601, 16.1234])
#  MaskedRate{UnitRate}(UnitRate(), [7.08131, 11.9684] ∪ [13.8928, 19.1363])
#  MaskedRate{UnitRate}(UnitRate(), [1.62054, 4.47242] ∪ [8.97044, 10.338])
#  ⋮
#  MaskedRate{UnitRate}(UnitRate(), [8.82903, 15.6189] ∪ [15.9772, 18.5621] ∪ [18.9563, 20])
#  MaskedRate{UnitRate}(UnitRate(), [1.03416, 6.50542] ∪ [8.53452, 14.9442] ∪ [15.154, 18.8697])
#  MaskedRate{UnitRate}(UnitRate(), [2.66274, 4.33029] ∪ [4.9079, 10.4581] ∪ [17.771, 20])
#  MaskedRate{UnitRate}(UnitRate(), [3.09921, 3.48972] ∪ [4.14111, 8.99342] ∪ [9.87407, 11.8905] ∪ [17.6349, 20])
#  MaskedRate{UnitRate}(UnitRate(), [0.854005, 6.74727] ∪ [10.2651, 12.9133] ∪ [12.9618, 14.2749] ∪ [19.4875, 20])
#  MaskedRate{UnitRate}(UnitRate(), [8.53335, 13.0764]ᵤ)
#  MaskedRate{UnitRate}(UnitRate(), [2.82985, 10.042] ∪ [12.7922, 16.184] ∪ [17.3183, 20])
#  MaskedRate{UnitRate}(UnitRate(), [2.16474, 7.01246] ∪ [9.48524, 15.1761] ∪ [16.6851, 19.954])
#  MaskedRate{UnitRate}(UnitRate(), [0.455546, 3.27128] ∪ [4.41639, 9.22921] ∪ [19.3572, 20])
#  MaskedRate{UnitRate}(UnitRate(), [1.38802, 5.29662] ∪ [5.56055, 13.7535] ∪ [14.712, 15.5169] ∪ [17.0075, 18.4836])
#  MaskedRate{UnitRate}(UnitRate(), [0.379937, 2.80124] ∪ [3.26005, 3.64917] ∪ [5.11984, 8.95742] ∪ [12.6207, 20])
#  MaskedRate{UnitRate}(UnitRate(), [0.401663, 1.47564] ∪ [1.53308, 4.67728] ∪ [6.26397, 8.59522] ∪ [11.7382, 20])

# %%
getpar(p,a1,b1,c1,a2,b2,c2) = [fill(p, 1, N);
     fill(a1, 1, N); fill(b1, 1, N); fill(c1, 1, N);
     fill(a2,   1, N); fill(b2, 1, N); fill(c2, 1, N)]
# Out:
# getpar (generic function with 1 method)

# %%
ε = 1e-10
λ = 0.6
θp = getpar(1/N, ε, T/2, 1/ε,   1.0, T/2, 1/ε)
θmin = getpar(ε  , ε  ,  -T,   ε,   ε,  -T, ε  )
θmax = getpar(1-ε, 1/ε,  2T, 1/ε, 1/ε,  2T, 1/ε)
const I = IndividualSI{GaussianRate,GaussianRate}
# Out:
# IndividualSI{GaussianRate, GaussianRate}

# %%
out = GaussianRate(λ, 7., 4.)
Mp = StochasticModel(I, T, θp, G, out, V);
sample! = Sampler(Mp);

# %%
ε = 2e-3
θp2 = getpar(1/N, ε, T/2, 1/ε,   1.0, T/2, 1/ε)
Mp2 = StochasticModel(I, T, θp2, G, out, V);

# %%
θ = getpar(2/N  , 2/N  ,  T/2,   2*T,   1,  T/2, 3*T  )
M = StochasticModel(I, T, θ, G, out, V);

# %%
avg = 0
for st = 1:10000
    xtrue = zeros(N)
    sample!(xtrue)
    avg += sum(xtrue .< T)
end
println("Average number of infected=$(round((avg/10000),digits=2)) over a population of $N individuals")
# Out:
# Average number of infected=12.91 over a population of 30 individuals

# %%
xtrue = zeros(N)
sample!(xtrue)
println("number of infected=$(round(sum(xtrue .< T),digits=2)) over a population of $N individuals")
nobs, p = 5, 1e-6
O = [(ti = T*(1+rand())/2; (i,xtrue[i] < ti,ti,p)) for i=1:nobs]
# Out:
# number of infected=16.0 over a population of 30 individuals
# 5-element Vector{Tuple{Int64, Bool, Float64, Float64}}:
#  (1, 0, 19.322831813229286, 1.0e-6)
#  (2, 0, 10.97906314786615, 1.0e-6)
#  (3, 1, 10.562420245878773, 1.0e-6)
#  (4, 0, 13.119995039464097, 1.0e-6)
#  (5, 0, 16.267957891473387, 1.0e-6)

# %% [markdown]
# Inference
# ===

# %%
using ProgressMeter
ProgressMeter.ijulia_behavior(:clear)
descend!(Mp2, O; M=M, numsamples=500, numiters=100, 
         θmin=θmin, θmax=θmax, descender=SignDescender(0.1));
descend!(Mp2, O; M=M, numsamples=5000, numiters=100, 
         θmin=θmin, θmax=θmax, descender=SignDescender(0.02));
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:16
#   F:  5.087141173646365

# %%
function histo(v; bins=20, up=1.0)
    h = zeros(bins+1)
    z = length(v)
    for x in v
        h[floor(Int, x*bins/up)+1]+=1/z
    end
    h
end
# Out:
# histo (generic function with 1 method)

# %%
stats = post(Mp, O, numsamples=10^4);
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:51

# %%
statscau = prior(M, numsamples=10^6);
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:18

# %%
using Plots
pl = map(1:30) do k
    p = plot()
    bar!(p, 0:M.T/20:M.T, histo((@view statscau[:, k]), up=M.T), alpha=0.5, xlims=(0,M.T+0.5), bins=20, label="cau", legend=false);
    bar!(p, 0:M.T/20:M.T, histo((@view stats[:, k]), up=M.T),    alpha=0.5, xlims=(0,M.T+0.5), bins=20, label="true", legend=false);
end;
plot(pl..., size=(800,600))

# %% [markdown]
# ## Marginals and ROC curve

# %%
function marginal(i, t, stats)
    numsamp = size(stats,2)
    sum(stats[:,i] .< t)/numsamp
end

function tpr(xtrue, rank) 
    cumsum(xtrue[rank]) ./( cumsum(xtrue[rank])[end])
end

function fpr(xtrue, rank) 
    N = size(rank,1)
    return (range(1,N,length=N) .- cumsum(xtrue[rank])) ./ (range(1,N,length=N) .- cumsum(xtrue[rank]) )[end]
end

function ROC(xtrue, p)
    N = size(xtrue,1)
    rank = sortperm(p, rev=true)
    
    return fpr(xtrue, rank) , tpr(xtrue, rank)
end

function AUROC(ROC)
    N = size(ROC[1],1) 
    AU = 0
    for t = 1:N-1
        AU += ROC[2][t] * (ROC[1][t+1] - ROC[1][t])
    end
    return AU
end
# Out:
# AUROC (generic function with 1 method)

# %%
#Let us find the ROC of the infected individuals at time t

t = T
epidemic_risk=zeros(N)
true_risk=zeros(N)
for i=1:N
   epidemic_risk[i] = marginal(i,t,statscau)
   true_risk[i] = marginal(i,t,stats)
end
xt = xtrue .< t
plot(ROC(xt, epidemic_risk)[1],ROC(xt, epidemic_risk)[2], label="ROC", title="Causality VS Exact ROC at time t=$t")
plot!(ROC(xt, true_risk)[1],ROC(xt, true_risk)[2], label="exactROC")

# %%
T = Int(T)
AU_curve=zeros(T)
AU_exact=zeros(T)
for t = 1:T
    epidemic_risk=zeros(N)
    true_risk=zeros(N)
    for i=1:N
       epidemic_risk[i] = marginal(i,t,statscau)
       true_risk[i] = marginal(i,t,stats)
    end
    xt = xtrue .< t
    AU_curve[t] = AUROC(ROC(xt, epidemic_risk))
    AU_exact[t] = AUROC(ROC(xt, true_risk))
end

plot(LinRange(1,T,T),AU_curve, label="AUROC", title="Causality VS Exact AUROC in function of time")
plot!(LinRange(1,T,T),AU_exact, label="AUexact")
xlabel!("t")
ylabel!("AUROC")
